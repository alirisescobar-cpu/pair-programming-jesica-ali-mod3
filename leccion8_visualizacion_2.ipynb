# %%
 #primero nuestras librerias!

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd

# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %%
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

# %%
df=pd.read_csv("files/world_data_full_apply_nulos.csv",index_col=0)
df.head()
# Out:
#        country  density abbreviation  agricultural_land  land_area  \
# 0  Afghanistan     60.0           AF               58.1    652.230
# 1      Albania    105.0           AL               43.1     28.748
# 2      Algeria     18.0           DZ               17.4        NaN
# 3      Andorra    164.0           AD               40.0    468.000
# 4       Angola     26.0           AO               47.5        NaN
#
#    armed_forces_size  birth_rate  calling_code capital/major_city  \
# 0              323.0       32.49          93.0              Kabul
# 1                9.0       11.78         355.0             Tirana
# 2              317.0       24.28         213.0            Algiers
# 3                NaN        7.20         376.0   Andorra la Vella
# 4              117.0       40.73         244.0             Luanda
#
#    co2-emissions     cpi  cpi_change currency-code  fertility_rate  \
# 0          8.672  149.90         2.3           AFN            4.47
# ...

# %%
#1)¿Cuál es el continente con la mayor cantidad de países en el conjunto de datos? Proporciona el porcentaje de países en ese continente.

#2)¿Cuáles son los 10 países con la mayor área forestal?

#3)¿Cómo se distribuye la densidad de población entre los continentes?

#4)¿Existe una relación entre el PIB y la tasa de desempleo de los países?

# %%
#1)¿Cuál es el continente con la mayor cantidad de países en el conjunto de datos? Proporciona el porcentaje de países en ese continente.

df_paises=df.groupby("continent")["country"].count().reset_index()
df_paises
# Out:
#          continent  country
# 0           Africa       53
# 1             Asia       45
# 2  Central America       20
# 3           Europe       47
# 4    North America        2
# 5          Oceania       14
# 6    South America       13

# %%
df_paises.shape
# Out:
# (7, 2)

# %%
df_porcentaje = (df_paises / df.shape[0])* 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df_porcentaje = (df_paises / df.shape[0])* 100
#
# File c:\Users\DAVID\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\ops\common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File c:\Users\DAVID\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\arraylike.py:214, in OpsMixin.__truediv__(self, other)
#     212 @unpack_zerodim_and_defer("__truediv__")
#     213 def __truediv__(self, other):
# --> 214     return self._arith_method(other, operator.truediv)
#
# ...

# %%
sns.barplot(data=df_paises, y="continent", x="country")/
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 sns.barplot(data=df_paises, y="continent", x="country")/100;
#
# TypeError: unsupported operand type(s) for /: 'Axes' and 'int'

# %%
top_10_forest = df.nlargest(10, 'forested_area')[['country', 'forested_area']]
top_10_forest
# Out:
#                             country  forested_area
# 167                        Suriname           98.3
# 111  Federated States of Micronesia           91.9
# 61                            Gabon           90.0
# 154                      Seychelles           88.4
# 132                           Palau           87.6
# 71                           Guyana           83.9
# 92                             Laos           82.1
# 159                 Solomon Islands           77.9
# 135                Papua New Guinea           74.1
# 59                          Finland           73.1

# %%
#2)¿Cuáles son los 10 países con la mayor área forestal?

sns.barplot(data=top_10_forest, y="country", x="forested_area");

# %%
sns.barplot(data=df_paises, y="country", x="forested_area");
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 sns.barplot(data=df_paises, y="country", x="forested_area");
#
# File c:\Users\DAVID\AppData\Local\Programs\Python\Python314\Lib\site-packages\seaborn\categorical.py:2341, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2338 if estimator is len:
#    2339     estimator = "size"
# -> 2341 p = _CategoricalAggPlotter(
#    2342     data=data,
#    2343     variables=dict(x=x, y=y, hue=hue, units=units, weight=weights),
#    2344     order=order,
#    2345     orient=orient,
#    2346     color=color,
#    2347     legend=legend,
#    2348 )
#    2350 if ax is None:
# ...
