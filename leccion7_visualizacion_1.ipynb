# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)

# %%
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

# %%
df_graficos = pd.read_csv("files/world_data_full_apply_nulos.csv", index_col=0)
df_graficos.head()
# Out:
#        country  density abbreviation  agricultural_land  land_area  \
# 0  Afghanistan     60.0           AF               58.1    652.230
# 1      Albania    105.0           AL               43.1     28.748
# 2      Algeria     18.0           DZ               17.4        NaN
# 3      Andorra    164.0           AD               40.0    468.000
# 4       Angola     26.0           AO               47.5        NaN
#
#    armed_forces_size  birth_rate  calling_code capital/major_city  \
# 0              323.0       32.49          93.0              Kabul
# 1                9.0       11.78         355.0             Tirana
# 2              317.0       24.28         213.0            Algiers
# 3                NaN        7.20         376.0   Andorra la Vella
# 4              117.0       40.73         244.0             Luanda
#
#    co2-emissions     cpi  cpi_change currency-code  fertility_rate  \
# 0          8.672  149.90         2.3           AFN            4.47
# 1          4.536  119.05         1.4           ALL            1.62
# 2        150.006  151.36         2.0           DZD            3.02
# 3        469.000     NaN         NaN           EUR            1.27
# 4         34.693  261.73        17.1           AOA            5.52
#
#    forested_area  gasoline_price           gdp  \
# 0            2.1            0.70  1.910135e+10
# 1           28.1            1.36  1.527808e+10
# 2            0.8            0.28  1.699882e+11
# 3           34.0            1.51  3.154058e+09
# 4           46.3            0.97  9.463542e+10
#
#    gross_primary_education_enrollment  gross_tertiary_education_enrollment  \
# 0                               104.0                                  9.7
# 1                               107.0                                 55.0
# 2                               109.9                                 51.4
# 3                               106.4                                  NaN
# 4                               113.5                                  9.3
#
#    infant_mortality      largest_city  life_expectancy  \
# 0              47.9             Kabul             64.5
# 1               7.8            Tirana             78.5
# 2              20.1           Algiers             76.7
# 3               2.7  Andorra la Vella              NaN
# 4              51.6            Luanda             60.8
#
#    maternal_mortality_ratio  minimum_wage official_language  \
# 0                     638.0          0.43            Pashto
# 1                      15.0          1.12          Albanian
# 2                     112.0          0.95            Arabic
# 3                       NaN          6.63           Catalan
# 4                     241.0          0.71        Portuguese
#
#    out_of_pocket_health_expenditure  physicians_per_thousand  population  \
# 0                              78.4                     0.28         NaN
# 1                              56.9                     1.20         NaN
# 2                              28.1                     1.72         NaN
# 3                              36.4                     3.33      77.142
# 4                              33.4                     0.21         NaN
#
#    population_labor_force_participation  tax_revenue  total_tax_rate  \
# 0                                  48.9          9.3            71.4
# 1                                  55.7         18.6            36.6
# 2                                  41.2         37.2            66.1
# 3                                   NaN          NaN             NaN
# 4                                  77.5          9.2            49.1
#
#    unemployment_rate  urban_population   latitude  longitude continent
# 0              11.12               NaN  33.939110  67.709953      Asia
# 1              12.33               NaN  41.153332  20.168331    Europe
# 2              11.70               NaN  28.033886   1.659626    Africa
# 3                NaN            67.873  42.506285   1.521801    Europe
# 4               6.89               NaN -11.202692  17.873887    Africa

# %%
A lo largo de este ejercicio plantearemos una serie de preguntas que tendrás que contestar usando la visualización (podréis usar tanto Seaborn como Matplotlib).

¿Cómo se distribuye la tasa de natalidad en el conjunto de datos? ¿Hay algún patrón evidente?

¿Existe una relación aparente entre la tasa de mortalidad infantil y la esperanza de vida? Proporciona una breve descripción de los patrones que observes.

¿Cuál es la mediana de la esperanza de vida en Europa? Proporciona un rango intercuartil aproximado y verifica si existen valores atípicos.

¿Existen relaciones visibles entre la tasa de natalidad y las siguientes variables: tasa de mortalidad infantil, esperanza de vida, densidad de población y población urbana? Usa un subplot. Describe cualquier patrón que encuentres.

Requisitos que deben cumplir las gráficas (en caso de usar alguna de ellas):

Todas deben llevar título.

Los nombres de los ejes deben estar en castellano.

En los scatterplot los puntos deben tener un tamaño de 2.

En los scatterplot los puntos deben tener un color diferente al azul.

En los barplot las barras siempre tienen que estar ordenadas de mayor a menor.

En los barplot y countplot las barras tienen que tener un color diferente a los que vienen por defecto.

En los pieplot siempre tenemos que añadir la etiqueta de a que % corresponde cada quesito.

# %%
df_graficos.columns
# Out:
# Index(['country', 'density', 'abbreviation', 'agricultural_land', 'land_area',
#        'armed_forces_size', 'birth_rate', 'calling_code', 'capital/major_city',
#        'co2-emissions', 'cpi', 'cpi_change', 'currency-code', 'fertility_rate',
#        'forested_area', 'gasoline_price', 'gdp',
#        'gross_primary_education_enrollment',
#        'gross_tertiary_education_enrollment', 'infant_mortality',
#        'largest_city', 'life_expectancy', 'maternal_mortality_ratio',
#        'minimum_wage', 'official_language', 'out_of_pocket_health_expenditure',
#        'physicians_per_thousand', 'population',
#        'population_labor_force_participation', 'tax_revenue', 'total_tax_rate',
#        'unemployment_rate', 'urban_population', 'latitude', 'longitude',
#        'continent'],
#       dtype='str')

# %%
sns.histplot(data=df_graficos, x="birth_rate", color = "purple", 
             kde = True, bins=15);

# %%
df_graficos[["continent"]].describe()
# Out:
#        continent
# count        194
# unique         7
# top       Africa
# freq          53

# %%
df_graficos.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 36 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   country                               195 non-null    str
#  1   density                               195 non-null    float64
#  2   abbreviation                          188 non-null    str
#  3   agricultural_land                     188 non-null    float64
#  4   land_area                             165 non-null    float64
#  5   armed_forces_size                     166 non-null    float64
#  6   birth_rate                            189 non-null    float64
#  7   calling_code                          194 non-null    float64
#  8   capital/major_city                    192 non-null    str
#  9   co2-emissions                         183 non-null    float64
#  10  cpi                                   175 non-null    float64
#  11  cpi_change                            179 non-null    float64
#  12  currency-code                         180 non-null    str
#  13  fertility_rate                        188 non-null    float64
#  14  forested_area                         188 non-null    float64
#  15  gasoline_price                        175 non-null    float64
#  16  gdp                                   193 non-null    float64
#  17  gross_primary_education_enrollment    188 non-null    float64
#  18  gross_tertiary_education_enrollment   183 non-null    float64
#  19  infant_mortality                      189 non-null    float64
#  20  largest_city                          189 non-null    str
#  21  life_expectancy                       187 non-null    float64
#  22  maternal_mortality_ratio              181 non-null    float64
#  23  minimum_wage                          150 non-null    float64
#  24  official_language                     190 non-null    str
#  25  out_of_pocket_health_expenditure      188 non-null    float64
#  26  physicians_per_thousand               188 non-null    float64
#  27  population                            39 non-null     float64
#  28  population_labor_force_participation  176 non-null    float64
#  29  tax_revenue                           169 non-null    float64
#  30  total_tax_rate                        183 non-null    float64
#  31  unemployment_rate                     176 non-null    float64
#  32  urban_population                      45 non-null     float64
#  33  latitude                              194 non-null    float64
#  34  longitude                             194 non-null    float64
#  35  continent                             194 non-null    str
# dtypes: float64(29), str(7)
# memory usage: 55.0 KB

# %%
sns.boxplot(data=df_graficos, x="birth_rate");

# %% [markdown]
# Tasa de natalidad: los valores se concentran aq la izquierda, la mediana de los valores esta en 18 (por cada mil habitantes), la mitad de los valores se encuentra entre 11 y 29.
# el 75% de los paises tienen una tasa inferior a 29

# %%
#¿Existe una relación aparente entre la tasa de mortalidad infantil y la esperanza de vida? Proporciona una breve descripción de los patrones que observes

plt.scatter(x = "life_expectancy", 
            y = "infant_mortality", 
            data = df_graficos, 
            c = "purple", 
            s = 2)

# %%
sns.regplot(x = "life_expectancy", 
            y = "infant_mortality", 
            data = df_graficos)
# Out:
# <Axes: xlabel='life_expectancy', ylabel='infant_mortality'>

# %% [markdown]
# Pareciera hacer una relacion inversa entre mortalidad infantil y esperanza de vida. Donde los paises con esperanza de vida alta, tienen menor mortalidad infantil.
# En Asia hay mucha variablidad pero la tendencia sigue siendo inversa.
# Hemos detectado que en Africa es donde hay menor esperanza de vida y mayor mortalidad infantil.

# %%
sns.scatterplot(x = "life_expectancy", 
            y = "infant_mortality", 
            hue = "continent",
            data = df_graficos)
# Out:
# <Axes: xlabel='life_expectancy', ylabel='infant_mortality'>

# %%
sns.scatterplot(data=df_graficos[df_graficos["continent"]=="Asia"], x="life_expectancy", y="infant_mortality");

# %%
sns.scatterplot(data=df_graficos[df_graficos["continent"]=="Africa"], x="life_expectancy", y="infant_mortality");

# %%
#Cuál es la mediana de la esperanza de vida en Europa? Proporciona un rango intercuartil aproximado y verifica si existen valores atípicos.

sns.boxplot(data=df_graficos[df_graficos["continent"]=="Europe"], x="life_expectancy");

# %% [markdown]
# La esperanza de vida en Europa es entre 72-85 años. El rango intercuartil (50%) de los datos estan entre 76 y 82, y la mediana es 81 años. Es interesante que hay 25% de los datos en 81 años.

# %%
#¿Existen relaciones visibles entre la tasa de natalidad y las siguientes variables: tasa de mortalidad infantil, esperanza de vida, densidad de población y población urbana? Usa un subplot. Describe cualquier patrón que encuentres.

# %%
# YA HEMOS AÑADIDO UNA GRÁFICA EN NUESTRO SUBPLOT, PERO NO TIENE NINGUNA DE LAS MODIFICACIONES QUE HICIMOS EN LA ORIGINAL.
# establecemos el número de filas, columnas que queremos así como el tamaño que vamos a querer que tenga la figura. 
fig, axes = plt.subplots(nrows = 1, ncols = 2, figsize = (20, 5))

# Vamos a empezar a insertar alguna gráfica, en concreto vamos a rellenar la primera (la de la izquierda) con el regplot que creamos anteriormente
# fijaos como no cambia nada, lo unico que hemos hecho ha sido añadir el parémtro 'ax' para hacer referencia en cual de los subplots lo queremos
# en este caso pondremos ax = 0, porque ya sabemos que en Python todo empieza siempre en 0. 
sns.regplot(x = "birth_rate", y = "life_expectancy", data = df_graficos, 
            marker = "d", 
            line_kws = {"color": "black", "linewidth": 1}, # cambiamos el color y el grosor de la linea de tendencia
            scatter_kws = {"color": "teal", "s": 1}, # cambiamos el color y el tamaño de los puntos del scaterplot
            ax = axes[0] # especificamos el eje en el que queremos poner la gráfica. En este caso en el eje 0. 
            )

# AÑADIMOS LA INFORMACIÓN QUE QUEREMOS EN EL SEGUNDO SUBPLOT, AÑADIENDO EL PARÁMETRO 'AX'. En este caso pondremos ax = axes[1] porque queremos que vaya en el segundo subplot. 
sns.scatterplot(x = "birth_rate", y = "urban_population", data = df_graficos, 
                size = 5, 
                marker= "v", 
                ax = axes[1])

sns.regplot(x = "birth_rate", y = "infant_mortality", data = df_graficos, 
            marker = "d", 
            line_kws = {"color": "black", "linewidth": 1}, # cambiamos el color y el grosor de la linea de tendencia
            scatter_kws = {"color": "teal", "s": 1}, # cambiamos el color y el tamaño de los puntos del scaterplot
            ax = axes[0])

;
# Out:
# ''
